# %%
aspects = ['AMBIENCE#GENERAL', 'DRINKS#PRICES', 'DRINKS#QUALITY', 'DRINKS#STYLE&OPTIONS', 'FOOD#PRICES', 'FOOD#QUALITY', 'FOOD#STYLE&OPTIONS',
           'LOCATION#GENERAL', 'RESTAURANT#GENERAL', 'RESTAURANT#MISCELLANEOUS', 'RESTAURANT#PRICES', 'SERVICE#GENERAL']
total = [1133, 236, 1013, 646, 558, 2771, 2183, 519, 1253, 726, 585, 1517]

# %%
import matplotlib.pyplot as plt

plt.pie(total, labels=aspects, autopct='%1.1f%%')
plt.title('Restaurant Aspect Distribution')
plt.show()

# %%
aspects = ['SERVICE#GENERAL', 'HOTEL#GENERAL', 'ROOMS#CLEANLINESS', 'LOCATION#GENERAL', 'HOTEL#COMFORT', 'ROOM_AMENITIES#GENERAL', 'HOTEL#PRICES',
           'ROOMS#DESIGN&FEATURES', 'ROOMS#COMFORT', 'FOOD&DRINKS#QUALITY', 'HOTEL#QUALITY', 'HOTEL#DESIGN&FEATURES', 'FOOD&DRINKS#STYLE&OPTIONS',
           'ROOMS#GENERAL', 'ROOM_AMENITIES#QUALITY', 'ROOMS#QUALITY', 'HOTEL#CLEANLINESS', 'FACILITIES#GENERAL', 'OTHER ASPECTS']
total = [3196, 1685, 1480, 1329, 1277, 977, 875, 676, 538, 509, 397, 396, 372, 341, 308, 297, 261, 226, 259]

# %%
plt.pie(total, labels=aspects, autopct='%1.1f%%')
plt.title('Hotel Aspect Distribution')
plt.show()

# %%
train = [5046+749+1466, 2491+339+672+1659+227+491]

plt.bar(['Positive', 'Negative'], train)
plt.title('Restaurant Sentiment Distribution')
plt.show()

# %%
train = [8714+967+2383,613+71+173+1570+180+469]

plt.bar(['Positive', 'Negative'], train)
plt.title('Hotel Sentiment Distribution')
plt.show()
